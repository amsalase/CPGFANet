# %%
import cv2
import numpy as np


# Load RGB image and thermal image
rgb_image = cv2.imread('/workspace/PST900_RGBT_Dataset/test/rgb/58_bag21_rect_rgb_frame0000000440.png')
thermal_image = cv2.imread('/workspace/PST900_RGBT_Dataset/test/thermal/58_bag21_rect_rgb_frame0000000440.png', cv2.IMREAD_GRAYSCALE)

if rgb_image is None:
    print("Error: Could not load RGB image")
    exit()
if thermal_image is None:
    print("Error: Could not load thermal image")
    exit()

# Merge RGB and thermal images into a 4-channel image
merged_image = cv2.merge((rgb_image[:,:,0], rgb_image[:,:,1], rgb_image[:,:,2], thermal_image))

# %%
print(rgb_image.shape)
print(thermal_image.shape)
# Out:
# (720, 1280, 3)
# (720, 1280)

# %%
plt.imshow(rgb_image)

# %%
plt.imshow(thermal_image)

# %%
import matplotlib.pyplot as plt

# Display merged image
plt.imshow(merged_image)
plt.show()

# %%
print(merged_image.shape)
# Out:
# (720, 1280, 4)

# %%
# Load RGB image and thermal image
rgb_MFNet_image = cv2.imread('/workspace//Dataset_MFNet/seperated_images//00001D_rgb.png')
thermal_MFNet_image = cv2.imread('/workspace//Dataset_MFNet/seperated_images//00001D_th.png', cv2.IMREAD_GRAYSCALE)

if rgb_image is None:
    print("Error: Could not load RGB image")
    exit()
if thermal_image is None:
    print("Error: Could not load thermal image")
    exit()

# Merge RGB and thermal images into a 4-channel image
merged_MFNet_image = cv2.merge((rgb_MFNet_image[:,:,0], rgb_MFNet_image[:,:,1], rgb_MFNet_image[:,:,2], thermal_MFNet_image))

# %%
plt.imshow(rgb_MFNet_image)

# %%
plt.imshow(thermal_MFNet_image)

# %%
plt.imshow(merged_MFNet_image)

# %%
print(rgb_image.shape)
print(thermal_image.shape)

# %%
print(merged_MFNet_image.shape)

# %%
import cv2
import sys
import numpy as np
np.set_printoptions(threshold=sys.maxsize)
import matplotlib.pyplot as plt
# Load RGB image and thermal image
rgb_image = cv2.imread('/workspace/Dataset_MFNet/visual/00124D.jpg')
plt.imshow(rgb_image)

# %%
print(rgb_image[305,410,2])
# Out:
# 127
